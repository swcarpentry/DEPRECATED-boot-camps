# %% [markdown]
# Ethan's magical mystery tour of Scientific Python
# -------------------------------------------------
#
# Import statements load code

# %%
import numpy
import matplotlib.pyplot as plt

# %%
data = numpy.genfromtxt('faithful.dat', delimiter=' ', skip_header=1)
eruptions = data[:, 0]
waiting_time = data[:, 1]
waiting_time_hrs = waiting_time / 60

# %% [markdown]
# Graphical Exploration of Eruption Data
# --------------------------------------
#
# 1. Relationships between eruption time and magnitude
# 2. Frequency distributions of both variables

# %%
plt.plot(waiting_time, eruptions, 'ro')

# %%
# %load_ext rmagic

# %%
# %%R
# a <- c(1, 2, 3)
# print(a)
# Out:
# [1] 1 2 3
