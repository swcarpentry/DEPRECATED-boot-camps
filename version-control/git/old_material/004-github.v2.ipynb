# %%
from IPython.display import Image
from IPython.display import display

# %% [markdown]
# # Using github as a research tool

# %% [markdown]
# # About Github

# %% [markdown]
# - Github is a code-sharing website. The most popular of its kind
# - It hosts source-code to many popular software projects, but not only

# %%
Image(filename='images/bundestag_github.png')

# %%
Image(filename='images/bundesgesetze_github.png')

# %% [markdown]
# # The German Constitution

# %% [markdown]
# If 3M users and 5M repositories aren't reason enough for you, maybe $100M in round A seed funding from Andreessen Horowitz is?
